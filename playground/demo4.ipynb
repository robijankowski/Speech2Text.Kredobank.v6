# %%
from whisper_correctors_utilities import split_transcription_into_roles, split_transcription_into_roles_verbose, find_unclear_words
from whisper_correctors_utilities import transcript_audio_file, transcript_audio_file_verbose
from display_utilities import print_text_as_table, print_text_as_plain
AUDIO_FILES = [
    "./Sources/2 380976776096 Кобець Т. 06.02.wav",
    "./Sources/380975854673 Люція Гродзицька 08.05.wav",
    "./Sources/5 380972851516 Ковальчук М. 21.06.wav",
    "./Sources/6 380671202008 Воробець І. 23.03.wav",
    "./Sources/6 380974345718 Гасяк А. 27.06.wav" 
]

# %%
audio_file = AUDIO_FILES[0]

# %%
transcription_verbose = transcript_audio_file_verbose(audio_file, temperature=0.2)
print_text_as_plain(transcription_verbose.text)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 16px; color: darkblue;"><tr><th style="text-align:left; border-bottom: 1px solid #ddd;"><b>Text</b></th></tr><tr><td style="border-bottom: 1px solid #ddd;text-align:left">Але доброго дня, доброго, це Ірина Анатолієвна, так, мене звати Кобець Тетяна Юрійовна, телефоную до вас з Кредобанку, зручно розмовляти? Так, так, повідомляю, що наша розмова записується, кажіть, будь ласка, дату народження для ідентифікації? 9.06.1983. Дякую, все вірно, телефонують стосовно угоди №339205, від 28.10.2021. За цією угодою у вас є претерміноване заборгування, у сумі 2040 грн. Підскажіть, коли плануєте вносити оплату? Ну, якщо це можливо, тому що ви ж бачите, яка з часу обстановка, то я по можливості, ви ж бачите, що я стараюся все робити до кінця наступного тижня. До кінця наступного тижня. Скажіть, чи не потрібна вам реструктуризація заборгованості? Я думаю, що ні. Ні, не потрібна, ні. Добре, тоді домовляємося, зараз перегляну, коли у вас наступний платіж, 28 числа. До 28 я внесу усе. Добре, тоді домовляємося, кінець наступного тижня, це буде 17 лютого. До 17 лютого домовляємося про оплату 2040 грн. І тоді до 28-го вже ваш плановий платіж. Добре, тоді так домовляємось, будемо чекати на оплату. Дякую вам за розмови. Дякую вам. До побачення.</td></tr></table>

# %%
roles = split_transcription_into_roles(transcription_verbose.text)
print_text_as_table(roles)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 16px; color: darkblue;"><tr><th style="width:50px; text-align:left; border-bottom: 1px solid #ddd;"><b>Role</b></th><th style="text-align:left; border-bottom: 1px solid #ddd;"><b>Text</b></th></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Але доброго дня, доброго, це Ірина Анатолієвна, так, мене звати Кобець Тетяна Юрійовна, телефоную до вас з Кредобанку, зручно розмовляти?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Так, так,</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">повідомляю, що наша розмова записується, кажіть, будь ласка, дату народження для ідентифікації?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">9.06.1983.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Дякую, все вірно, телефонують стосовно угоди №339205, від 28.10.2021. За цією угодою у вас є претерміноване заборгування, у сумі 2040 грн. Підскажіть, коли плануєте вносити оплату?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Ну, якщо це можливо, тому що ви ж бачите, яка з часу обстановка, то я по можливості, ви ж бачите, що я стараюся все робити до кінця наступного тижня.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">До кінця наступного тижня. Скажіть, чи не потрібна вам реструктуризація заборгованості?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Я думаю, що ні.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Ні, не потрібна, ні. Добре, тоді домовляємося, зараз перегляну, коли у вас наступний платіж, 28 числа.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">До 28 я внесу усе.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Добре, тоді домовляємося, кінець наступного тижня, це буде 17 лютого. До 17 лютого домовляємося про оплату 2040 грн. І тоді до 28-го вже ваш плановий платіж. Добре, тоді так домовляємось, будемо чекати на оплату. Дякую вам за розмови.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Дякую вам.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">До побачення.</td></tr></table>

# %%
roles_verbose = split_transcription_into_roles_verbose(transcription_verbose)
print_text_as_table(roles_verbose)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 16px; color: darkblue;"><tr><th style="width:50px; text-align:left; border-bottom: 1px solid #ddd;"><b>Role</b></th><th style="text-align:left; border-bottom: 1px solid #ddd;"><b>Text</b></th></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Але доброго дня, доброго, це Ірина Анатолієвна, так, мене звати Кобець Тетяна Юрійовна, телефоную до вас з Кредобанку,</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">зручно розмовляти?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Так, так, повідомляю, що наша розмова записується, кажіть, будь ласка, дату народження для ідентифікації?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">9.06.1983. Дякую, все вірно, телефонують стосовно угоди №339205, від 28.10.2021. За цією угодою у вас є претерміноване заборгування, у сумі 2040 грн.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Підскажіть, коли плануєте вносити оплату?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Ну, якщо це можливо, тому що ви ж бачите, яка з часу обстановка, то я по можливості, ви ж бачите, що я стараюся все робити до кінця наступного тижня.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">До кінця наступного тижня. Скажіть, чи не потрібна вам реструктуризація заборгованості?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Я думаю, що ні. Ні, не потрібна, ні.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Добре, тоді домовляємося, зараз перегляну, коли у вас наступний платіж, 28 числа.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">До 28 я внесу усе.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Добре, тоді домовляємося, кінець наступного тижня, це буде 17 лютого. До 17 лютого домовляємося про оплату 2040 грн. І тоді до 28-го вже ваш плановий платіж.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Добре, тоді так домовляємось, будемо чекати на оплату. Дякую вам за розмови.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Дякую вам.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">До побачення.</td></tr></table>

13049, 1055, 2873, 8403, 20455, 1679, 4178, 7683, 25834, 585, 945, 5254, 11726, 489, 13, 23297, 1069, 1435, 1827, 5865, 7562, 12, 4567, 40738, 14536, 23443, 1055, 6251, 34160, 1827, 1820, 13, 51064], 'temperature': 0.20000000298023224, 'avg_logprob': -0.27393099665641785, 'compression_ratio': 2.035874366760254, 'no_speech_prob': 0.8433637022972107}
# {'id': 7, 'seek': 7700, 'start': 91.0, 'end': 99.0, 'text': ' Добре, тоді так домовляємось, будемо чекати на оплату. Дякую вам за розмови. Дякую вам.', 'tokens': [51064, 3401, 13829, 387, 11, 1069, 1435, 1827, 2936, 13049, 1055, 2873, 8403, 919, 8049, 11, 23213, 354, 1358, 2872, 9585, 1470, 7683, 25834, 585, 13, 3401, 681, 35119, 10448, 4396, 20681, 43632, 435, 13, 3401, 681, 35119, 10448, 13, 51464], 'temperature': 0.20000000298023224, 'avg_logprob': -0.27393099665641785, 'compression_ratio': 2.035874366760254, 'no_speech_prob': 0.8433637022972107}
# {'id': 8, 'seek': 7700, 'start': 99.0, 'end': 101.0, 'text': ' До побачення.', 'tokens': [51464, 31695, 20024, 8314, 25568, 13, 51564], 'temperature': 0.20000000298023224, 'avg_logprob': -0.27393099665641785, 'compression_ratio': 2.035874366760254, 'no_speech_prob': 0.8433637022972107}

# %%
audio_file = AUDIO_FILES[1]

# %%
transcription_verbose = transcript_audio_file_verbose(audio_file, temperature=0.2)
print_text_as_plain(transcription_verbose.text)

# %%
roles = split_transcription_into_roles(transcription_verbose.text)
print_text_as_table(roles)

# %%
roles_verbose = split_transcription_into_roles_verbose(transcription_verbose)
print_text_as_table(roles_verbose)

# %%
audio_file = AUDIO_FILES[2]

# %%
transcription_verbose = transcript_audio_file_verbose(audio_file, temperature=0.2)
print_text_as_plain(transcription_verbose.text)

# %%
roles = split_transcription_into_roles(transcription_verbose.text)
print_text_as_table(roles)

# %%
roles_verbose = split_transcription_into_roles_verbose(transcription_verbose)
print_text_as_table(roles_verbose)

# %%
audio_file = AUDIO_FILES[3]

# %%
transcription_verbose = transcript_audio_file_verbose(audio_file, temperature=0.2)
print_text_as_plain(transcription_verbose.text)

# %%
roles = split_transcription_into_roles(transcription_verbose.text)
print_text_as_table(roles)

# %%
roles_verbose = split_transcription_into_roles_verbose(transcription_verbose)
print_text_as_table(roles_verbose)

# %%
audio_file = AUDIO_FILES[4]

# %%
transcription_verbose = transcript_audio_file_verbose(audio_file, temperature=0.2)
print_text_as_plain(transcription_verbose.text)

# %%
roles = split_transcription_into_roles(transcription_verbose.text)
print_text_as_table(roles)

# %%
roles_verbose = split_transcription_into_roles_verbose(transcription_verbose)
print_text_as_table(roles_verbose)

# %%
text_check_verbose = find_unclear_words(transcription_verbose.text)
print_text_as_plain(text_check_verbose)
