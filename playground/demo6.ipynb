# %% [markdown]
# <h1>AUDIO FILE 1</h1>

# %%
audio_file = get_audio_file(1, AUDIO_FILES)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 20px; color: darkblue;"><tr><th style="text-align:left; border-bottom: 1px solid #ddd;"><b></b></th></tr>
#         <tr>
#             <td style="border-bottom: 1px solid #ddd;text-align:left">
#                 <b>2 380976776096 Кобець Т. 06.02.wav</b> <br>
#                 <audio controls>
#                     <source src="./Sources/2 380976776096 Кобець Т. 06.02.wav" type="audio/mpeg">
#                     Your browser does not support the audio element.
#                 </audio>
#             </td>
#         </tr></table>

# %%
transcription_verbose = transcript_audio_file_verbose(audio_file)
print_text_as_plain(transcription_verbose.text)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 16px; color: darkblue;"><tr><th style="text-align:left; border-bottom: 1px solid #ddd;"><b>Text</b></th></tr><tr><td style="border-bottom: 1px solid #ddd;text-align:left">Але доброго дня, це Ірина Анатоліївна, мене звати Кобець Тетяна Юрійвна, телефоную до вас з Кредобанку, зручно розмовляти? Так, так, повідомляю, що наша розмова записується, кажіть будь ласка, дату народження для ідентифікації? 9.06.1983 Дякую, все вірно, телефонують стосовно угоди № 339205, від 28.10.2021. За цією угодою у вас є претерміноване заборгування в сумі 2040 грн. Так, я знаю, так Підскажіть, коли плануєте вносити оплату? Якщо це можливо, тому що ви ж бачите, яка сьогодні обстановка, то я по можливості, ви ж бачите, що я стараюся це робити до кінця наступного тижня До кінця наступного тижня? Так Скажіть, чи не потрібна вам реструктуризація заборгованості? Я думаю, що ні, не потрібна, ні Добре, тоді домовляємося, зараз перегляну, коли у вас наступний платіж, 28.10.2021 До 28.10.2021 я внесу усе Так, добре, тоді домовляємося, кінець наступного тижня, це буде 17.02.2021, до 17.02.2021 домовляємося про оплату 2040 грн. Так І тоді до 28.01.2021 вже ваш плановий платіж Так, так Добре, тоді так домовляємося, будемо очікувати на оплату Так Дякую вам за розмови на наступного тижня Дякую вам До побачення До побачення</td></tr></table>

# %%
roles = split_transcription_into_roles(transcription_verbose.text)
print_text_as_table(roles)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 16px; color: darkblue;"><tr><th style="width:50px; text-align:left; border-bottom: 1px solid #ddd;"><b>Role</b></th><th style="text-align:left; border-bottom: 1px solid #ddd;"><b>Text</b></th></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Але доброго дня, це Ірина Анатоліївна, мене звати Кобець Тетяна Юрійвна, телефоную до вас з Кредобанку, зручно розмовляти?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Так, так, повідомляю, що наша розмова записується, кажіть будь ласка, дату народження для ідентифікації?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">9.06.1983</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Дякую, все вірно, телефонують стосовно угоди № 339205, від 28.10.2021. За цією угодою у вас є претерміноване заборгування в сумі 2040 грн.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Так, я знаю, так</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Підскажіть, коли плануєте вносити оплату?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Якщо це можливо, тому що ви ж бачите, яка сьогодні обстановка, то я по можливості, ви ж бачите, що я стараюся це робити до кінця наступного тижня</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">До кінця наступного тижня?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Так</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Скажіть, чи не потрібна вам реструктуризація заборгованості?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Я думаю, що ні, не потрібна, ні</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Добре, тоді домовляємося, зараз перегляну, коли у вас наступний платіж, 28.10.2021</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">До 28.10.2021 я внесу усе</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Так, добре, тоді домовляємося, кінець наступного тижня, це буде 17.02.2021, до 17.02.2021 домовляємося про оплату 2040 грн.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Так</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">І тоді до 28.01.2021 вже ваш плановий платіж</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Так, так</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Добре, тоді так домовляємося, будемо очікувати на оплату</td></tr><tr><td style ...

# %% [markdown]
# <h1>AUDIO FILE 2</h1>

# %%
audio_file = get_audio_file(2, AUDIO_FILES)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 20px; color: darkblue;"><tr><th style="text-align:left; border-bottom: 1px solid #ddd;"><b></b></th></tr>
#         <tr>
#             <td style="border-bottom: 1px solid #ddd;text-align:left">
#                 <b>380975854673 Люція Гродзицька 08.05.wav</b> <br>
#                 <audio controls>
#                     <source src="./Sources/380975854673 Люція Гродзицька 08.05.wav" type="audio/mpeg">
#                     Your browser does not support the audio element.
#                 </audio>
#             </td>
#         </tr></table>

# %%
transcription_verbose = transcript_audio_file_verbose(audio_file)
print_text_as_plain(transcription_verbose.text)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 16px; color: darkblue;"><tr><th style="text-align:left; border-bottom: 1px solid #ddd;"><b>Text</b></th></tr><tr><td style="border-bottom: 1px solid #ddd;text-align:left">Алло, доброго дня. Тетяна Миколаївна, Гетьман. Все телефонують вам з Кредобанку, мене звати Гродзицька, Люція Івановна, повідомляю, що телефонна розмова записується. Для ідентифікації вас як клієнта банку, дату народження, назвіть, будь ласка. 9.12. І рік, будь ласка? 81. Тетяна Миколаївна, телефоную вам стосовно готівкового кредитного договору, з яким на сьогодні існує протермінована заборгованість у сумі 2485 гривень, за номером угоди це 168 369 від 11 лютого 2019 року. Яка причина, що невиконані оплати своєчасно згідно договору виникли? Немає зараз коштів, затримують заробітну плату. Ви офіційно працюєте? Так. Ну, в принципі, на офіційному місці праці не повинні затримувати, бо є певне законодавче регулювання цього, але тим не менш можливий такий варіант. Є, нас цілий місяць затримають, податки сплачують вчасно, але заробітну плату саме затримують. Зрозуміло. Але принаймні найближчим часом хоча б вам гарантують повернення? Так, в нас орієнтовно виплатить раз в місяць після 20-го, бо десь в районі 20-х числів. Ну, тут ситуація є з наступною. У вас, я бачу, був наданий певний пільговий період, так, по договору, ну і, відповідно, два платежі трішки менші, як два платежі, бо сума платежу у вас 1525 гривень на 11-те число, фактично два місяці, і це вам за рахунок цього вже кількість днів просрочених 84 тому. З превеликим би бажанням вам надала такий термін після 20-го числа, звісно, можливо частково зможете здійснити собі певне погашення загальної цієї суми, бо на 11-те число вам вже додається ще один плавановий платіж до всієї суми, розумієте? Угу. І тільки вам від того не зменшиться, що ви не готові всю суму відразу собі провести, тобто протерміновану і планову платіж. Так, я розумію, до 20-го взагалі планують тисячу гривень внести. Ця ситуація вам не змінить кардинально проблеми в тому, що є така кількість днів. Чим до 90-го днів принаближається та кількість, тим ймовірніше справою будуть займатися вже відділ стягнення. Є певна процедура банку, спробуйте все-таки собі таку змогу знайти, принаймні зараз до 11-го хоча б якийсь частковий платіж, щоб зменшити кількість прострочених днів, ну і після 20-го таким чином потрішки виправити дану ситуацію. Так, добре постараюсь. В межах якої суми ви би могли до 11-го числа, щоб вирішилося це питання хоча б? Тисяча гривень. Тисяча гривень ви би змогли внести. Ану секундочку, я відразу перегляну. Як нам? Значить, вам би кількість днів, явно, щоби скоротилась від цієї оплати, яку ви виправили, але пам'ятаєте, до 11-го, бо 11-го там вже піде списання вам, включаючи травень місяць. Тому, якщо до 11-го ви це зробите, то кількість днів буде дійсно кардинально зменшена, і таким чином ви ще будете мати хоча б трішки часу тими плановими платежами, відповідно, нас догнати той графік, який у вас є насправді. Тому, власне, я занотую, що до 10-ти країн у вас здійсниться собі це погашення, і далі дотримуватиметься погашення подальшої суми протормінованої заборговності. Дуже добре. Дякую за розмову. Нам все добре. Дякую.</td></tr></table>

# %%
roles = split_transcription_into_roles(transcription_verbose.text)
print_text_as_table(roles)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 16px; color: darkblue;"><tr><th style="width:50px; text-align:left; border-bottom: 1px solid #ddd;"><b>Role</b></th><th style="text-align:left; border-bottom: 1px solid #ddd;"><b>Text</b></th></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Алло, доброго дня. Тетяна Миколаївна, Гетьман. Все телефонують вам з Кредобанку, мене звати Гродзицька, Люція Івановна, повідомляю, що телефонна розмова записується. Для ідентифікації вас як клієнта банку, дату народження, назвіть, будь ласка.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">9.12.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">І рік, будь ласка?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">81.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Тетяна Миколаївна, телефоную вам стосовно готівкового кредитного договору, з яким на сьогодні існує протермінована заборгованість у сумі 2485 гривень, за номером угоди це 168 369 від 11 лютого 2019 року. Яка причина, що невиконані оплати своєчасно згідно договору виникли?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Немає зараз коштів, затримують заробітну плату.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Ви офіційно працюєте?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Так.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Ну, в принципі, на офіційному місці праці не повинні затримувати, бо є певне законодавче регулювання цього, але тим не менш можливий такий варіант.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Є, нас цілий місяць затримають, податки сплачують вчасно, але заробітну плату саме затримують.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Зрозуміло. Але принаймні найближчим часом хоча б вам гарантують повернення?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Так, в нас орієнтовно виплатить раз в місяць після 20-го, бо десь в районі 20-х числів.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Ну, тут ситуація є з наступною. У вас, я бачу, був наданий певний пільговий період, так, по договору, ну і, відповідно, два платежі трішки менші, як два платежі, бо сума платежу у вас 1525 гривень на 11-те число, фактично два місяці, і це вам за рахунок цього вже кількість днів просрочених 84 тому. З превеликим би бажанням вам надала такий термін після 20-го числа, звісно, можливо частково зможете здійснити собі певне погашення загальної цієї суми, бо на 11-те число вам вже додається ще один плавановий платіж до всієї суми, розумієте?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Угу.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td s ...

# %% [markdown]
# <h1>AUDIO FILE 3</h1>

# %%
audio_file = get_audio_file(3, AUDIO_FILES)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 20px; color: darkblue;"><tr><th style="text-align:left; border-bottom: 1px solid #ddd;"><b></b></th></tr>
#         <tr>
#             <td style="border-bottom: 1px solid #ddd;text-align:left">
#                 <b>5 380972851516 Ковальчук М. 21.06.wav</b> <br>
#                 <audio controls>
#                     <source src="./Sources/5 380972851516 Ковальчук М. 21.06.wav" type="audio/mpeg">
#                     Your browser does not support the audio element.
#                 </audio>
#             </td>
#         </tr></table>

# %%
transcription_verbose = transcript_audio_file_verbose(audio_file)
print_text_as_plain(transcription_verbose.text)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 16px; color: darkblue;"><tr><th style="text-align:left; border-bottom: 1px solid #ddd;"><b>Text</b></th></tr><tr><td style="border-bottom: 1px solid #ddd;text-align:left">Алло, добрий день, телефонуємо з Кредобанку, мене звати Марта, мій порядковий номер 1080, це Сиренка Юрій Віталійович? Так, так. Добре, повідомляю, що наша розмова записується, до вас телефонують по угоді CL 307 637 від 08.04.2021 року. Бачу, що станом на 20.06 по цій угоді у вас є протермінована заборгованість 3303 грн, підскажіть, будь ласка, чому не оплачуєте, що трапилось? Трапилось? Що розказати? Я зараз виконую обов'язки в ЗСУ, тому трошки я, так, проштрафлююсь, бо не до того. Чекаю на бойові, десь 20-х числах тоді закину. 20-х числах цього місяця, я правильно розумію? Так, так. Добре, а, будь ласка, вам не кажуть конкретної дати, коли це виплачують? На жаль, на жаль, ні. Добре, а є ймовірність, що до кінця тижня оплатили? Є ймовірність, так. Зазвичай з 21 по 25 вже щось надходить. Добре, давайте тоді я зафіксую на 23 червня оплату, це в нас є п'ятниця. Добре? Давайте на 25, тому що я ж не можу за наше міністерство сказати. Зафіксую на 25 червня оплату в розмірі 3 303 гривні. Зараз я ще перегляну, чи є у вас ще якісь угоди, діючи хвилинку. Нормально було. Ну і так. Висуває. Так. Зараз хвилинку, Юрій Віталійович. Поки що зафіксую по цій угоді домовленість на 25 червня. Будемо очікувати зарахування. Гарного дня вам, до побачення. Дуже дякую, до побачення. До побачення.</td></tr></table>

# %%
roles = split_transcription_into_roles(transcription_verbose.text)
print_text_as_table(roles)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 16px; color: darkblue;"><tr><th style="width:50px; text-align:left; border-bottom: 1px solid #ddd;"><b>Role</b></th><th style="text-align:left; border-bottom: 1px solid #ddd;"><b>Text</b></th></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Алло, добрий день, телефонуємо з Кредобанку, мене звати Марта, мій порядковий номер 1080, це Сиренка Юрій Віталійович?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Так, так.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Добре, повідомляю, що наша розмова записується, до вас телефонують по угоді CL 307 637 від 08.04.2021 року. Бачу, що станом на 20.06 по цій угоді у вас є протермінована заборгованість 3303 грн, підскажіть, будь ласка, чому не оплачуєте, що трапилось?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Трапилось? Що розказати? Я зараз виконую обов'язки в ЗСУ, тому трошки я, так, проштрафлююсь, бо не до того. Чекаю на бойові, десь 20-х числах тоді закину.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">20-х числах цього місяця, я правильно розумію?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Так, так.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Добре, а, будь ласка, вам не кажуть конкретної дати, коли це виплачують?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">На жаль, на жаль, ні.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Добре, а є ймовірність, що до кінця тижня оплатили?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Є ймовірність, так. Зазвичай з 21 по 25 вже щось надходить.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Добре, давайте тоді я зафіксую на 23 червня оплату, це в нас є п'ятниця. Добре?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Давайте на 25, тому що я ж не можу за наше міністерство сказати.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Зафіксую на 25 червня оплату в розмірі 3 303 гривні. Зараз я ще перегляну, чи є у вас ще якісь угоди, діючи хвилинку.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Нормально було. Ну і так. Висуває. Так.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Зараз хвилинку, Юрій Віталійович. Поки що зафіксую по цій угоді домовленість на 25 червня. Будемо очікувати зарахування. Гарного дня вам, до побачення.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Дуже дякую, до побачення.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><t ...

# %% [markdown]
# <h1>AUDIO FILE 4</h1>

# %%
audio_file = get_audio_file(4, AUDIO_FILES)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 20px; color: darkblue;"><tr><th style="text-align:left; border-bottom: 1px solid #ddd;"><b></b></th></tr>
#         <tr>
#             <td style="border-bottom: 1px solid #ddd;text-align:left">
#                 <b>6 380671202008 Воробець І. 23.03.wav</b> <br>
#                 <audio controls>
#                     <source src="./Sources/6 380671202008 Воробець І. 23.03.wav" type="audio/mpeg">
#                     Your browser does not support the audio element.
#                 </audio>
#             </td>
#         </tr></table>

# %%
transcription_verbose = transcript_audio_file_verbose(audio_file)
print_text_as_plain(transcription_verbose.text)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 16px; color: darkblue;"><tr><th style="text-align:left; border-bottom: 1px solid #ddd;"><b>Text</b></th></tr><tr><td style="border-bottom: 1px solid #ddd;text-align:left">Алло, доброго дня, Алло, Людмила Олексійовна, телефонують до вас з Кредобанку, звати мене Іван, порядковий номер 1081, телефонуємо з приводу незакритого питання, наша розмова з вами записується, для проведення процедури ідентифікації, звучте, будь ласка, дату вашого народження, 08.05.1967, З приводу кредитного договору, номер угоди CL-305351, дата угоди від 23.03.2021, протермінована сума 53 152 грн 34 копійки, коли планується виплата по боргу? Наразі нічого не бачимо, а на рецентралізацію з яким платежем ви розраховуєте? Наразі ми документів жодних не отримували, нічого не відображається, давайте тоді домовимося з вами так, яку суму ви можете оплатити до понеділка, 27 березня мінімально? Дві тисячі ВПО, які місячно, дві тисячі, ви не знаєте, скільки ви платуєте ВПО? ВПО виплачували 6 500. Хто це виплачував, коли, ви що, це допомога, ООН. Ви не працюєте? Я не працюю, тому що я в Дергачах, взагалі, працювала, а зараз я живу далеко, а тут нема, шукаю роботу, але я живу в такому селі, в якому немає роботи. А на біржу плаці ви вставали, підкажіть, будь ласка. Ні, я ще не розрахована з постійного місця роботи, мене до іюня місяця ще не розраховують, в іюні вже буду розраховуватися, може на біржу встану. В вас не розраховують з роботи, ви отримуєте ВПО 2 тисячі гривень, на біржу праці ви не стаєте, як ви думаєте обслуговувати кредитну заборгованості? Думаю, за часом. Зміняється робота, ставайте на біржу праці, з часом вашу справу передадуть в юридичний департамент, передадуть арешти. На що? У мене немає нічого, у мене будинок розрушений, повністю до тла згорів, на що ви будете накладати мені арешти? На що? На мою життю? Або на що? Ні, виконавчі слуги, ви накладаєте арешти на рахунок. Це не моє, не моя прихача, я не плачу, я завжди справно платив. Я розумію, давайте тоді заплатити тисячу гривень до понеділка 27 березня, цілком підйомна сума за півроку провести такий платіж. Ну добре, тисяча гривень не питання, допустимо, я заплачу, так. Ми вважаємо на ваші документи до понеділка 27 березня, яка є більше 100 тисяч гривень. Добре, подивіться, можна... Будуть питання, звертайтеся, слухаю вас. Питання є, можна зараз я запитаю? Так. Скажіть, на який рахунок мені заплатити? Зараз, от в цей момент, в мене немає можливості виїхати до Харкова і дотриматися банку, або оплатити. Ну от в мене є приватна карточка приватбанку на телефоні банку, я можу заплатити з неї. Ну на який рахунок? Пришліть мені рахунок, будь ласка, якщо що. Зараз до вас прийде смс з рахунком. Так, я на цей рахунок можу приватбанку відправити? Звісно, що зможеш. Ну, пришліть, будь ласка, тому що в мене документи всі згоріли. Ось ті, які я оплачувала, кредит, в мене нічого на руках зараз немає. Зрозуміло, відправляємо вам. Добре? Так, відправляйте, будь ласка. До побачення. До побачення.</td></tr></table>

# %%
roles = split_transcription_into_roles(transcription_verbose.text)
print_text_as_table(roles)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 16px; color: darkblue;"><tr><th style="width:50px; text-align:left; border-bottom: 1px solid #ddd;"><b>Role</b></th><th style="text-align:left; border-bottom: 1px solid #ddd;"><b>Text</b></th></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Алло, доброго дня, Алло, Людмила Олексійовна, телефонують до вас з Кредобанку, звати мене Іван, порядковий номер 1081, телефонуємо з приводу незакритого питання, наша розмова з вами записується, для проведення процедури ідентифікації, звучте, будь ласка, дату вашого народження.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">08.05.1967.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">З приводу кредитного договору, номер угоди CL-305351, дата угоди від 23.03.2021, протермінована сума 53 152 грн 34 копійки, коли планується виплата по боргу? Наразі нічого не бачимо, а на рецентралізацію з яким платежем ви розраховуєте? Наразі ми документів жодних не отримували, нічого не відображається, давайте тоді домовимося з вами так, яку суму ви можете оплатити до понеділка, 27 березня мінімально?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Дві тисячі ВПО, які місячно, дві тисячі, ви не знаєте, скільки ви платуєте ВПО? ВПО виплачували 6 500.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Хто це виплачував, коли, ви що, це допомога, ООН. Ви не працюєте?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Я не працюю, тому що я в Дергачах, взагалі, працювала, а зараз я живу далеко, а тут нема, шукаю роботу, але я живу в такому селі, в якому немає роботи.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">А на біржу плаці ви вставали, підкажіть, будь ласка.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Ні, я ще не розрахована з постійного місця роботи, мене до іюня місяця ще не розраховують, в іюні вже буду розраховуватися, може на біржу встану.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">В вас не розраховують з роботи, ви отримуєте ВПО 2 тисячі гривень, на біржу праці ви не стаєте, як ви думаєте обслуговувати кредитну заборгованості?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Думаю, за часом.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Зміняється робота, ставайте на біржу праці, з часом вашу справу передадуть в юридичний департамент, передадуть арешти.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">На що? У мене немає нічого, у мене будинок розрушений, повністю до тла згорів, на що ви будете накладати мені арешти? На що? На мою життю? Або на що?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Ні, виконавчі слуги, ви накладаєте арешти на рахунок.</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bo ...

# %% [markdown]
# <h1>AUDIO FILE 5</h1>

# %%
audio_file = get_audio_file(5, AUDIO_FILES)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 20px; color: darkblue;"><tr><th style="text-align:left; border-bottom: 1px solid #ddd;"><b></b></th></tr>
#         <tr>
#             <td style="border-bottom: 1px solid #ddd;text-align:left">
#                 <b>6 380974345718 Гасяк А. 27.06.wav</b> <br>
#                 <audio controls>
#                     <source src="./Sources/6 380974345718 Гасяк А. 27.06.wav" type="audio/mpeg">
#                     Your browser does not support the audio element.
#                 </audio>
#             </td>
#         </tr></table>

# %%
transcription_verbose = transcript_audio_file_verbose(audio_file)
print_text_as_plain(transcription_verbose.text)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 16px; color: darkblue;"><tr><th style="text-align:left; border-bottom: 1px solid #ddd;"><b>Text</b></th></tr><tr><td style="border-bottom: 1px solid #ddd;text-align:left">Доброго дня, до вас телефонують з Кредобанку, мене звати Анна, мій порядковий номер 1075, це є Поліщук Володимир Олексійович, повідомляємо, наша розмова з вами записується, у вашому договору ЦЛ 171210 від 1 березня 2019 року, станом на 25 червня, у вас заборгованість є у розмірі 927 гривень, бачу, домовлялися щодо вплати на 23 червня, що сталося? Не пішли гроші, на цьому тижні повинні прийти, гроші зроблені, все є, їх не пішли, по цьому договору небагато, в мене по-другому більша сума, я вже хотів разом поїхати заплатити Ну так, але ви собі руйнуєте кредитну історію, що очікуєте? Я вже знаю, а казав, дай Бог їх виплатить, казав, ніхто їх більше брати не буде, діло в тому, що не прийшли, погано розраховується, гроші зароблені є, обіцяли, що на цьому тижні, вже підрудь у кінця місяця, обіцяли на додому Ага, добре, тобто, так, по готівковому кредиту так само, коли будете здійснювати, платіш? Бо тут я бачу по готівковому кредиту бачу 28 тисяч 418 гривень за орган Я ж за нього і кажу, за два, у мене два готівкових Так, ще суму на 300 тисяч гривень, так, і по ньому, ви будете здійснювати 30 червня? Ну, старте вже на кінець місяця, хто прийде завтра, завтра, не знаю, може сьогодні прийдуть Тобто ви не знаєте, а яку суму будете по цьому готівковому великому? Не знаю, нічого не знаю, скільки заплатять, там у мене зароблено, казав, що можна було в цілому кредиту не закрити, і ні фіга не розраховується Ага, побачив, що воно, почуть, почуть, почутають Тобто ви не знаєте, чи ви здійсняте платіш 28 тисяч 418 гривень, чи це буде 15 тисяч, так? Ну, так, я не знаю, я не знаю, але буду старатися по максимуму По максимуму, тобто фіксувати по готівковому кредиту на 30 червня всю суму, так, 28 тисяч 418 гривень, про термінування Буду старатися, побачив, що воно вийде, якщо прийде така сума, то заплачу Ага, скажіть, будь ласка, і по другому готівковому кредиту 930 гривень, так? Так Добре, очікуємо зарахувань, гарного дня вам, до побачення Вам теж гарного дня</td></tr></table>

# %%
roles = split_transcription_into_roles(transcription_verbose.text)
print_text_as_table(roles)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 16px; color: darkblue;"><tr><th style="width:50px; text-align:left; border-bottom: 1px solid #ddd;"><b>Role</b></th><th style="text-align:left; border-bottom: 1px solid #ddd;"><b>Text</b></th></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Доброго дня, до вас телефонують з Кредобанку, мене звати Анна, мій порядковий номер 1075, це є Поліщук Володимир Олексійович, повідомляємо, наша розмова з вами записується, у вашому договору ЦЛ 171210 від 1 березня 2019 року, станом на 25 червня, у вас заборгованість є у розмірі 927 гривень, бачу, домовлялися щодо вплати на 23 червня, що сталося?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Не пішли гроші, на цьому тижні повинні прийти, гроші зроблені, все є, їх не пішли, по цьому договору небагато, в мене по-другому більша сума, я вже хотів разом поїхати заплатити</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Ну так, але ви собі руйнуєте кредитну історію, що очікуєте?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Я вже знаю, а казав, дай Бог їх виплатить, казав, ніхто їх більше брати не буде, діло в тому, що не прийшли, погано розраховується, гроші зароблені є, обіцяли, що на цьому тижні, вже підрудь у кінця місяця, обіцяли на додому</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Ага, добре, тобто, так, по готівковому кредиту так само, коли будете здійснювати, платіш? Бо тут я бачу по готівковому кредиту бачу 28 тисяч 418 гривень за орган</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Я ж за нього і кажу, за два, у мене два готівкових</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Так, ще суму на 300 тисяч гривень, так, і по ньому, ви будете здійснювати 30 червня?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Ну, старте вже на кінець місяця, хто прийде завтра, завтра, не знаю, може сьогодні прийдуть</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Тобто ви не знаєте, а яку суму будете по цьому готівковому великому?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Не знаю, нічого не знаю, скільки заплатять, там у мене зароблено, казав, що можна було в цілому кредиту не закрити, і ні фіга не розраховується</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Ага, побачив, що воно, почуть, почуть, почутають</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Тобто ви не знаєте, чи ви здійсняте платіш 28 тисяч 418 гривень, чи це буде 15 тисяч, так?</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Client:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">Ну, так, я не знаю, я не знаю, але буду старатися по максимуму</td></tr><tr><td style="border-bottom: 1px solid #ddd; text-align:left"><b>Agent:</b></td><td style="border-bottom: 1px solid #ddd;text-align:left">По максимуму, тобто фіксувати по готівковому кредиту ...

# %% [markdown]
# <h1>TOOLS</h1>

# %%
answer_text = ask_about_dialog("Did the Agent has introduced himself at the beginning of the conversation?", roles)
print_text_as_plain(answer_text)
# Out:
# <table style="width:100%; border-collapse: collapse; font-size: 16px; color: darkblue;"><tr><th style="text-align:left; border-bottom: 1px solid #ddd;"><b>Text</b></th></tr><tr><td style="border-bottom: 1px solid #ddd;text-align:left">Yes, the Agent introduced herself as Anna from Kredobank with the serial number 1075.</td></tr></table>
